# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %%
from cv2 import CascadeClassifier
from cv2 import imread
classifier = CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
pixels=imread('test.jpg')

# %%
bboxes = classifier.detectMultiScale(pixels)

# %%
from google.colab.patches import cv2_imshow
for box in bboxes:
	# extract
	x, y, width, height = box
	x2, y2 = x + width, y + height
	# draw a rectangle over the pixels
	rectangle(pixels, (x, y), (x2, y2), (0,0,255), 1)
# show the image
cv2_imshow(pixels)

# %%
cv2_imshow(pixels)

# %%
from cv2 import imread
from cv2 import imshow
from cv2 import waitKey
from cv2 import destroyAllWindows
from cv2 import CascadeClassifier
from cv2 import rectangle

# %%
for box in bboxes:
  x,y,width,height=box
  x2,y2=x+width,y+height
  rectangle(pixels,(x,y),(x2,y2),(0,0,225),3)
cv2_imshow(pixels)

# %%
pixels=imread('test2.jpg')

# %%
bboxes=classifier.detectMultiScale(pixels)
for box in bboxes:
  print(box)
# Out:
# [3126   46   74   74]
# [2348  233   95   95]
# [2958  592   34   34]
# [686 615  63  63]
# [1459  699  143  143]
# [1277  756  142  142]
# [1903  703  176  176]
# [1426  620  208  208]
# [4432  886   85   85]
# [4560  894   77   77]
# [271 819 187 187]
# [2473  903  219  219]
# [3907  984  100  100]
# [3366  790  171  171]
# [1807  917   53   53]
# [3895 1250   41   41]
# [3712 1152   60   60]
# [ 448 1303  176  176]
# [2857 1230  110  110]

# %%
for box in bboxes:
  x,y,width,height=box
  x2,y2=x+width,y+height
  rectangle(pixels,(x,y),(x2,y2),(0,0,225),5)
cv2_imshow(pixels)

# %%
! pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 34.6 MB/s
# ...

# %%
import mtcnn
print(mtcnn.__version__)
# Out:
# 0.1.0

# %%
from matplotlib import pyplot
from mtcnn.mtcnn import MTCNN
filename='test.jpg'
pixels=pyplot.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 3/3 [==============================] - 0s 32ms/step
# {'box': [745, 314, 338, 388], 'confidence': 0.9999982714653015, 'keypoints': {'left_eye': (831, 484), 'right_eye': (974, 442), 'nose': (917, 541), 'mouth_left': (872, 612), 'mouth_right': (1011, 575)}}
# {'box': [2935, 755, 748, 968], 'confidence': 0.9999778866767883, 'keypoints': {'left_eye': (3082, 1168), 'right_eye': (3419, 1157), 'nose': (3184, 1355), 'mouth_left': (3107, 1518), 'mouth_right': (3406, 1510)}}
# {'box': [14, 402, 384, 448], 'confidence': 0.9999733567237854, 'keypoints': {'left_eye': (122, 595), 'right_eye': (280, 539), 'nose': (231, 668), 'mouth_left': (181, 751), 'mouth_right': (337, 706)}}
# {'box': [2168, 307, 455, 598], 'confidence': 0.9998490810394287, 'keypoints': {'left_eye': (2313, 537), 'right_eye': (2542, 550), 'nose': (2426, 689), 'mouth_left': (2301, 746), 'mouth_right': (2510, 758)}}
# ...

# %%
from matplotlib.patches import Rectangle
def draw_image_with_boxes(filename,result_list):
  data=pyplot.imread(filename)
  pyplot.imshow(data)
  ax=pyplot.gca()
  for result in result_list:
    x,y,width,height=result['box']
    rect=Rectangle((x,y),width,height,fill=False,color='red')
    ax.add_patch(rect)

# %%
filename='test.jpg'
pixels=pyplot.imread(filename)
detector =MTCNN()
faces=detector.detect_faces(pixels)
draw_image_with_boxes(filename,faces)
# Out:
# ...
# 3/3 [==============================] - 0s 30ms/step

# %%
filename='test2.jpg'
pixels=pyplot.imread(filename)
detector =MTCNN()
faces=detector.detect_faces(pixels)
draw_image_with_boxes(filename,faces)
# Out:
# ...
# 5/5 [==============================] - 0s 38ms/step

# %%
import zipfile
def unzip_data(filename):
  zip_ref = zipfile.ZipFile(filename, "r")
  zip_ref.extractall()
  zip_ref.close()



unzip_data('/content/photos.zip')

# %%
import os
image_lables=[]
for fname in os.listdir('/content/photos/'):
  image_lables.append("/content/photos/"+fname)
print(image_lables)
image_lables.remove(image_lables[3])
# Out:
# ['/content/photos/11.jpg', '/content/photos/6.jpg', '/content/photos/3.jpg', '/content/photos/.ipynb_checkpoints', '/content/photos/9.jpg', '/content/photos/8.jpg', '/content/photos/10.jpg', '/content/photos/4.jpg', '/content/photos/1.jpg', '/content/photos/7.jpg', '/content/photos/2.jpg', '/content/photos/5.jpg']

# %%
for filename in image_lables:
  pixels=pyplot.imread(filename)
  detector =MTCNN()
  faces=detector.detect_faces(pixels)
  draw_image_with_boxes(filename,faces)
# Out:
# ...
# 3/3 [==============================] - 0s 42ms/step

# %%
import cv2
from google.colab.patches import cv2_imshow
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

img =cv2.imread('test9.jpg')

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

face=classifier.detectMultiScale(gray)

for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,225),3)

cv2_imshow(img)

# %%
import cv2
from google.colab.patches import cv2_imshow
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

img =cv2.imread('test9.jpg')



face=classifier.detectMultiScale(img)

for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,225),3)

cv2_imshow(img)

# %%
import cv2
from google.colab.patches import cv2_imshow
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

img =cv2.imread('test9.jpg')

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

face=classifier.detectMultiScale(gray)

for (x,y,w,h) in face:
  cv2.rectangle(gray,(x,y),(x+w,y+h),(0,0,225),3)

cv2_imshow(gray)

# %%
import cv2
from google.colab.patches import cv2_imshow
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

img =cv2.imread('test9.jpg')

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

face=classifier.detectMultiScale(gray,1.1)

for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,225),3)

cv2_imshow(img)

# %%
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

img =cv2.imread('test.JPG')

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

face=classifier.detectMultiScale(gray)

for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,225),3)
  roi_color = img[y:y + h, x:x + w]
  print("[INFO] Object found. Saving locally.")
  cv2.imwrite(str(w) + str(h) + '_faces.jpg', roi_color)

cv2_imshow(img)
# Out:
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F38A2125C90>

# %%
import numpy as np

img_rgb = cv2.imread('/content/faces/3030_faces.jpg')


img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)


template = cv2.imread('test9.jpg', 0)


w, h = template.shape[::-1]


res = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)


threshold = 0.8


loc = np.where(res >= threshold)

if res.all()>=threshold:
  print("yes")
else:
  print("no")

for pt in zip(*loc[::-1]):
	cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0, 255, 255), 2)


cv2_imshow(img_rgb)
# Out:
# no
# <PIL.Image.Image image mode=RGB size=30x30 at 0x7F389998D1D0>

# %%
img_rgb = cv2.imread('/content/faces/3030_faces.jpg')


img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)


template = cv2.imread('temp.JPG',0)


w, h = template.shape[::-1]


res = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)


threshold = 0.8


loc = np.where(res >= threshold)

if res.all()>=threshold:
  print("yes")
else:
  print("no")

for pt in zip(*loc[::-1]):
	cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0, 255, 255), 2)


cv2_imshow(img_rgb)
# Out:
# yes
# <PIL.Image.Image image mode=RGB size=30x30 at 0x7F389998D750>

# %%
import os
flable=[]
for filename in os.listdir('/content/faces/'):
  flable.append(filename)
print(flable)

imlable=[]
for fname in os.listdir('/content/images/'):
  imlable.append(fname)
  imlable.sort()
print(imlable)
# Out:
# ['5858_faces.jpg', '9999_faces.jpg', '5757_faces.jpg', '3232_faces.jpg', '3030_faces.jpg', '3131_faces.jpg', '4343_faces.jpg']
# ...

# %%
sol=[]

for face in imlable:
   img_rgb = cv2.imread('/content/faces/3232_faces.jpg')
   img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
   template = cv2.imread('/content/images/'+face, 0)
   w, h = template.shape[::-1]
   res = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)
   threshold = 0.8
   loc = np.where(res >= threshold)
   if res.all()>=threshold:
     sol.append("yes")
   else:
     sol.append("no")

   for pt in zip(*loc[::-1]):
     cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0, 255, 255), 2)

print(sol)
# Out:
# ['no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes']

# %%
for face in imlable:
  img=cv2.imread('/content/images/'+face)
  cv2_imshow(img)

# %%
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

img =cv2.imread('/content/images/0bdbbfcc-41b7-4b6e-8089-3c982a594739.JPG')

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

face=classifier.detectMultiScale(gray)

for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,225),3)
  roi_color = img[y:y + h, x:x + w]
  print("[INFO] Object found. Saving locally.")
  cv2.imwrite(str(w) + str(h) + '_faces.jpg', roi_color)

cv2_imshow(img)
# Out:
# [INFO] Object found. Saving locally.
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F38998FC750>

# %%
sol=[]

for face in flable:
   img_rgb = cv2.imread('/content/faces/5757_faces.jpg')
   img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
   template = cv2.imread('/content/faces/'+face, 0)
   w, h = template.shape[::-1]
   res = cv2.matchTemplate(img_gray, template, cv2.TM_SQDIFF)
   threshold = 0.8
   loc = np.where(res >= threshold)
   if res.all()>=threshold:
     sol.append("yes")
   else:
     sol.append("no")

   for pt in zip(*loc[::-1]):
     cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0, 255, 255), 2)

print(sol)
# Out:
# ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']

# %%
! pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 100.1 MB 12 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=e066e8a66271fe9b4c99bbb82cc2490a2a3a247c7a9164caf3983e2d0b5a278a
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
import imutils
import pickle
import time
import cv2
import os

#find path of xml file containing haarcascade file
cascPathface = os.path.dirname(
 cv2.__file__) + "/data/haarcascade_frontalface_alt2.xml"
# load the harcaascade in the cascade classifier
faceCascade = cv2.CascadeClassifier(cascPathface)
# load the known faces and embeddings saved in last file
data = pickle.loads(open('face_enc', "rb").read())
#Find path to the image you want to detect face and pass it here
image = cv2.imread(Path-to-img)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#convert image to Greyscale for haarcascade
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,
                                     scaleFactor=1.1,
                                     minNeighbors=5,
                                     minSize=(60, 60),
                                     flags=cv2.CASCADE_SCALE_IMAGE)

# the facial embeddings for face in input
encodings = face_recognition.face_encodings(rgb)
names = []
# loop over the facial embeddings incase
# we have multiple embeddings for multiple fcaes
for encoding in encodings:
    #Compare encodings with encodings in data["encodings"]
    #Matches contain array with boolean values and True for the embeddings it matches closely
    #and False for rest
    matches = face_recognition.compare_faces(data["encodings"],
    encoding)
    #set name =inknown if no encoding matches
    name = "Unknown"
    # check to see if we have found a match
    if True in matches:
        #Find positions at which we get True and store them
        matchedIdxs = [i for (i, b) in enumerate(matches) if b]
        counts = {}
        # loop over the matched indexes and maintain a count for
        # each recognized face face
        for i in matchedIdxs:
            #Check the names at respective indexes we stored in matchedIdxs
            name = data["names"][i]
            #increase count for the name we got
            counts[name] = counts.get(name, 0) + 1
            #set name which has highest count
            name = max(counts, key=counts.get)


        # update the list of names
        names.append(name)
        # loop over the recognized faces
        for ((x, y, w, h), name) in zip(faces, names):
            # rescale the face coordinates
            # draw the predicted face name on the image
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(image, name, (x, y), cv2.FONT_HERSHEY_SIMPLEX,
             0.75, (0, 255, 0), 2)
    cv2.imshow("Frame", image)
    cv2.waitKey(0)
